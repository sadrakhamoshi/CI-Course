# %% [markdown]
# <a href="https://colab.research.google.com/github/sadrakhamoshi/CI-Course/blob/main/CI992_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Your info
#
# Full name: Sadra khamoshi far
#
# Student ID: 97521261

# %% [markdown]
# Notice: **You can add new cells for each part.**

# %% [markdown]
# # Q1.A. Kohonen

# %%
#write your code here

## ***** NOTE : learning rate and radius not change and are constant ****** 


import matplotlib.pyplot as plt
import numpy as np

features = 3
data_num = 1600
epochs = 3200
learning_rate = 0.05
map_dimansion = (40, 40)
init_radius = max(map_dimansion[0],map_dimansion[1])
time_constant = epochs / np.log(init_radius)

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(121)
ax.title.set_text('Begin')

ax2 = fig.add_subplot(122)
ax2.title.set_text('SOFM')


def get_normal_data(data):
    normal_data = data / np.max(data)
    return normal_data


def get_data(input_dim=3):
    random_data_set = np.random.randint(0, 255, size=(data_num, input_dim))
    normalized_data = get_normal_data(random_data_set)
    return normalized_data


def initialize(map_dim, input_dim=3):
    x, y = map_dim
    weights = np.random.random((x, y, input_dim))
    return weights


# def update_radius(i):
#     return init_radius * np.exp(-i / time_constant)

# def update_learning_rate(i):
#     return learning_rate * np.exp(-i / time_constant)

def Gaussian_function(dist, radius):
    return np.exp(-dist / (2 * (radius**2)))

def get_bmu(x, w):
    diff = w - x
    diff = diff**2
    sum_diff = diff.sum(axis=2)
    ind = np.unravel_index(np.argmin(sum_diff, axis=None), sum_diff.shape)
    return ind


def update_weights(argmin, x, w, r, l, map_dim):
    x_dim, y_dim = map_dim
    idx = list(np.ndindex(x_dim, y_dim))
    idx_arr = np.array(idx).reshape((x_dim, y_dim, 2))
    diff = idx_arr - argmin
    diff_pow = diff**2
    sumd = diff_pow.sum(axis=2)
    dist = np.sqrt(sumd)
    out_of_radius = dist >= r
    dist[out_of_radius] = 0
    tmp = Gaussian_function(dist, r)
    tmp[out_of_radius] = 0
    gaussian = tmp.reshape((x_dim, y_dim, 1))
    dw = (l * gaussian) * (x - w)
    w = w + dw
    return w


def train(X, w):

    for i in range(epochs):
        # r = update_radius(i)
        # l = update_learning_rate(i)
        x = X[i % data_num]

        argmin = get_bmu(x, w)

        w = update_weights(argmin=argmin,
                           x=x,
                           w=w,
                           r=15.0,
                           l=learning_rate,
                           map_dim=map_dimansion)
        if i % 100 == 0 or i == epochs:
          print(f'epoch =====> {i} / {epochs}')
    ax2.imshow(w)

    return w


def main():
    data = get_data(input_dim= features)
    w = initialize(map_dim=map_dimansion, input_dim=features)
    ax.imshow(w)
    new_w = train(data, w)
    it = np.equal(new_w, w)
    plt.show()


if __name__ == '__main__':
    main()
# Out:
# epoch =====> 0 / 3200
# epoch =====> 100 / 3200
# epoch =====> 200 / 3200
# epoch =====> 300 / 3200
# epoch =====> 400 / 3200
# epoch =====> 500 / 3200
# epoch =====> 600 / 3200
# epoch =====> 700 / 3200
# epoch =====> 800 / 3200
# epoch =====> 900 / 3200
# epoch =====> 1000 / 3200
# epoch =====> 1100 / 3200
# epoch =====> 1200 / 3200
# epoch =====> 1300 / 3200
# epoch =====> 1400 / 3200
# epoch =====> 1500 / 3200
# epoch =====> 1600 / 3200
# epoch =====> 1700 / 3200
# epoch =====> 1800 / 3200
# epoch =====> 1900 / 3200
# epoch =====> 2000 / 3200
# epoch =====> 2100 / 3200
# epoch =====> 2200 / 3200
# epoch =====> 2300 / 3200
# epoch =====> 2400 / 3200
# epoch =====> 2500 / 3200
# epoch =====> 2600 / 3200
# epoch =====> 2700 / 3200
# epoch =====> 2800 / 3200
# epoch =====> 2900 / 3200
# epoch =====> 3000 / 3200
# epoch =====> 3100 / 3200

# %% [markdown]
# # Q1.B. Kohonen

# %%
#write your code here

## ***** NOTE : i combine both part b and c in first question it means both of learning rate and radius will change with time ***** 


import matplotlib.pyplot as plt
import numpy as np

features = 3
data_num = 1600
epochs = 3800
learning_rate = 0.05
map_dimansion = (40, 40)
print(map_dimansion[0])
init_radius = max(map_dimansion[0],map_dimansion[1])
time_constant = epochs / np.log(init_radius)

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(121)
ax.title.set_text('Begin')

ax2 = fig.add_subplot(122)
ax2.title.set_text('SOFM')


def get_normal_data(data):
    normal_data = data / np.max(data)
    return normal_data


def get_data(input_dim=3):
    random_data_set = np.random.randint(0, 255, size=(data_num, input_dim))
    normalized_data = get_normal_data(random_data_set)
    return normalized_data


def initialize(map_dim, input_dim=3):
    x, y = map_dim
    weights = np.random.random((x, y, input_dim))
    return weights


def update_radius(i):
    return init_radius * np.exp(-i / time_constant)


def update_learning_rate(i):
    return learning_rate * np.exp(-i / time_constant)


def Gaussian_function(dist, radius):
    return np.exp(-dist / (2 * (radius**2)))

def get_bmu(x, w):
    diff = w - x
    diff = diff**2
    sum_diff = diff.sum(axis=2)
    ind = np.unravel_index(np.argmin(sum_diff, axis=None), sum_diff.shape)
    return ind


def update_weights(argmin, x, w, r, l, map_dim):
    x_dim, y_dim = map_dim
    idx = list(np.ndindex(x_dim, y_dim))
    idx_arr = np.array(idx).reshape((x_dim, y_dim, 2))
    diff = idx_arr - argmin
    diff_pow = diff**2
    sumd = diff_pow.sum(axis=2)
    dist = np.sqrt(sumd)
    out_of_radius = dist >= r
    dist[out_of_radius] = 0
    tmp = Gaussian_function(dist, r)
    tmp[out_of_radius] = 0
    gaussian = tmp.reshape((x_dim, y_dim, 1))
    dw = (l * gaussian) * (x - w)
    w = w + dw
    return w


def train(X, w):

    for i in range(epochs):
        r = update_radius(i)
        l = update_learning_rate(i)
        x = X[i % data_num]

        argmin = get_bmu(x, w)

        w = update_weights(argmin=argmin,
                           x=x,
                           w=w,
                           r=r,
                           l=l,
                           map_dim=map_dimansion)
        if i % 100 == 0 or i == epochs:
          print(f'epoch =====> {i} / {epochs}')
    ax2.imshow(w)

    return w


def main():
    data = get_data(input_dim= features)
    w = initialize(map_dim=map_dimansion, input_dim=features)
    ax.imshow(w)
    new_w = train(data, w)
    it = np.equal(new_w, w)
    plt.show()


if __name__ == '__main__':
    main()

## Part C :
##  ****** NOTE : THIS PART IS A BIT DSICRIPTION FOR PART 3 OF FIRST QUESTION : IN HERE WE USE  update_radius(i) TO UPDATE THE RADIUS ******
# Out:
# 40
# epoch =====> 0 / 3800
# epoch =====> 100 / 3800
# epoch =====> 200 / 3800
# epoch =====> 300 / 3800
# epoch =====> 400 / 3800
# epoch =====> 500 / 3800
# epoch =====> 600 / 3800
# epoch =====> 700 / 3800
# epoch =====> 800 / 3800
# epoch =====> 900 / 3800
# epoch =====> 1000 / 3800
# epoch =====> 1100 / 3800
# epoch =====> 1200 / 3800
# epoch =====> 1300 / 3800
# epoch =====> 1400 / 3800
# epoch =====> 1500 / 3800
# epoch =====> 1600 / 3800
# epoch =====> 1700 / 3800
# epoch =====> 1800 / 3800
# epoch =====> 1900 / 3800
# epoch =====> 2000 / 3800
# epoch =====> 2100 / 3800
# epoch =====> 2200 / 3800
# epoch =====> 2300 / 3800
# epoch =====> 2400 / 3800
# epoch =====> 2500 / 3800
# epoch =====> 2600 / 3800
# epoch =====> 2700 / 3800
# epoch =====> 2800 / 3800
# epoch =====> 2900 / 3800
# epoch =====> 3000 / 3800
# epoch =====> 3100 / 3800
# epoch =====> 3200 / 3800
# epoch =====> 3300 / 3800
# epoch =====> 3400 / 3800
# epoch =====> 3500 / 3800
# epoch =====> 3600 / 3800
# epoch =====> 3700 / 3800

# %% [markdown]
# # Q2.A. MLP

# %%
#write your code here
from keras.layers import *
from keras.optimizers import *
from keras.models import Sequential
from keras.datasets import mnist
import numpy as np
import keras
import matplotlib.pyplot as plt


NUM_SAMPLES = 300
TEST_SAMPLES = 200
X_test = np.random.uniform(-np.pi, np.pi, TEST_SAMPLES)
X = np.random.uniform(-6.0, 6.0, NUM_SAMPLES)
X = np.sort(X, axis=0)
y = (np.sin(X) + 1) / 2

X = X.reshape((NUM_SAMPLES,1))
X_test = X_test.reshape((TEST_SAMPLES,1))
y = y.reshape((NUM_SAMPLES,1))

model = Sequential()
model.add(Dense(80, activation='relu',input_shape= (1,)))
model.add(Dense(40, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='SGD', loss='mean_squared_error', metrics=['accuracy'])
model.summary()

result = model.fit(x=X,y=y,epochs=2800,validation_split=0.1)
Y_predict = model.predict(X_test)


plt.plot(X.reshape(NUM_SAMPLES), 2*(y.reshape(NUM_SAMPLES)) -1 , 'y', label='expected')
plt.scatter(X_test.reshape(TEST_SAMPLES),2*( Y_predict.reshape(TEST_SAMPLES))-1, label='MLP')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 301/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1111 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 302/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1154 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 303/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1066 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 304/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1045 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 305/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1144 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 306/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1142 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 307/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 308/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1190 - accuracy: 0.0000e+00 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 309/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1084 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 310/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1083 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 311/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1169 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 312/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1122 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 313/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1060 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 314/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1109 - accuracy: 0.0000e+00 - val_loss: 0.0566 - val_accuracy: 0.0000e+00
# Epoch 315/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 316/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1205 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 317/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1010 - accuracy: 0.0000e+00 - val_loss: 0.0566 - val_accuracy: 0.0000e+00
# Epoch 318/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1159 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 319/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1097 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 320/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1155 - accuracy: 0.0000e+00 - val_loss: 0.0563 - val_accuracy: 0.0000e+00
# Epoch 321/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0566 - val_accuracy: 0.0000e+00
# Epoch 322/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1100 - accuracy: 0.0000e+00 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 323/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1198 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 324/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1102 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 325/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 326/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1184 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 327/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1132 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 328/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1112 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 329/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1111 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 330/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1119 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 331/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 332/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1132 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 333/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1105 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 334/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0987 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 335/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1187 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 336/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1238 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 337/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1178 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 338/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1177 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 339/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 340/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 341/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1131 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 342/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1113 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 343/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1117 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 344/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1123 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 345/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1084 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 346/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1197 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 347/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1172 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 348/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1159 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 349/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1129 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 350/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 351/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1111 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 352/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1132 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 353/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1121 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 354/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1225 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 355/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1167 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 356/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1123 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 357/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1206 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 358/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1145 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 359/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1096 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 360/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1100 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 361/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1138 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 362/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1095 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 363/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 364/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1114 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 365/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1156 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 366/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 367/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1119 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 368/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1113 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 369/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1044 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 370/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 371/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1158 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 372/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1072 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 373/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 374/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1123 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 375/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1111 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 376/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1099 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 377/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1018 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 378/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 379/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1150 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 380/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1151 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 381/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1100 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 382/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1017 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 383/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1152 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 384/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1019 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 385/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 386/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1134 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 387/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 388/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1093 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 389/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1100 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 390/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1142 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 391/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1152 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 392/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1096 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 393/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1124 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 394/2800
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1096 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 395/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1077 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 396/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1237 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 397/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1178 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 398/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1179 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 399/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1046 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 400/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1112 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 401/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1152 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 402/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 403/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1152 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 404/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1144 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 405/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 406/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1070 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 407/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1158 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 408/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1063 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 409/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1065 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 410/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1138 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 411/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1135 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 412/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1182 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 413/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1172 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 414/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1099 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 415/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1154 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 416/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1121 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 417/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1130 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 418/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1060 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 419/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1078 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 420/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 421/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1053 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 422/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1058 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 423/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 424/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1158 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 425/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 426/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1152 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 427/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1097 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 428/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1105 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 429/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1166 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 430/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1148 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 431/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1136 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 432/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1099 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 433/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1122 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 434/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1078 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 435/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1151 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 436/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1035 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 437/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 438/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1141 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 439/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1105 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 440/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1100 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 441/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1114 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 442/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1031 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 443/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1097 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 444/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1157 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 445/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1087 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 446/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1071 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 447/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1069 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 448/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 449/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1088 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 450/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1151 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 451/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1141 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 452/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1200 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 453/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1016 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 454/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 455/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1159 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 456/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 457/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1185 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 458/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 459/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1026 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 460/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1098 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 461/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1060 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 462/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1052 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 463/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1085 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 464/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1073 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 465/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1129 - accuracy: 0.0000e+00 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 466/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1184 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 467/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1084 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 468/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1123 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 469/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1101 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 470/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1058 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 471/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1075 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 472/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 473/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1131 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 474/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1149 - accuracy: 0.0000e+00 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 475/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 476/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1096 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 477/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1072 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 478/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1056 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 479/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1000 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 480/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1085 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 481/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1194 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 482/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1133 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 483/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 484/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1093 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 485/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1056 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 486/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 487/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1042 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 488/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1078 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 489/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 490/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 491/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 492/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1091 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 493/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1125 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 494/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1097 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 495/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 496/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1100 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 497/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 498/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1066 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 499/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1185 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 500/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1066 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 501/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0992 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 502/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1152 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 503/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1077 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 504/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1117 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 505/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1105 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 506/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1083 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 507/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1082 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 508/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 509/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1102 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 510/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 511/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1136 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 512/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1079 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 513/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1145 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 514/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1074 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 515/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1035 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 516/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1107 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 517/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 518/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1048 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 519/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 520/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 521/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 522/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1072 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 523/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1088 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 524/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1047 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 525/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1093 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 526/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1085 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 527/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1086 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 528/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1160 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 529/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1045 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 530/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 531/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1038 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 532/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 533/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1103 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 534/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1147 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 535/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1113 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 536/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1025 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 537/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1135 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 538/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1139 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 539/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 540/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1078 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 541/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1120 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 542/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0609 - val_accuracy: 0.0000e+00
# Epoch 543/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1086 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 544/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1096 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 545/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1099 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 546/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1144 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 547/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1144 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 548/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1035 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 549/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 550/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1057 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 551/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1086 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 552/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1118 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 553/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1077 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 554/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 555/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1081 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 556/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1093 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 557/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1087 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 558/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1063 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 559/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1040 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 560/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1128 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 561/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1066 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 562/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1110 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 563/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1140 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 564/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1088 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 565/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1078 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 566/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1033 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 567/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1074 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 568/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1128 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 569/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1069 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 570/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 571/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1063 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 572/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1021 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 573/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1080 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 574/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1090 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 575/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 576/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1082 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 577/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1079 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 578/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1050 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 579/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1120 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 580/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1012 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 581/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 582/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1050 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 583/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1097 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 584/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1082 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 585/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1130 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 586/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1034 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 587/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1103 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 588/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1145 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 589/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1006 - accuracy: 0.0000e+00 - val_loss: 0.0605 - val_accuracy: 0.0000e+00
# Epoch 590/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 591/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1104 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 592/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1062 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 593/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1086 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 594/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 595/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 596/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1095 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 597/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1007 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 598/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1060 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 599/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1004 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 600/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1071 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 601/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1036 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 602/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1047 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 603/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1072 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 604/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1094 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 605/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1061 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 606/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1069 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 607/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1114 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 608/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1068 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 609/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1069 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 610/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1048 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 611/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 612/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 613/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1030 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 614/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0982 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 615/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1040 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 616/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1093 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 617/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1067 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 618/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1119 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 619/2800
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 620/2800
# ...
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2696/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2697/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2698/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2699/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2700/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2701/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2702/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2703/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2704/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2705/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2706/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2707/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2708/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2709/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2710/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 2711/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2712/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2713/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2714/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2715/2800
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2716/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2717/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2718/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2719/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2720/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2721/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2722/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2723/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2724/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2725/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2726/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 2727/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2728/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2729/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2730/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2731/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2732/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2733/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2734/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2735/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2736/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2737/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2738/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2739/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2740/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2741/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2742/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 2743/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2744/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2745/2800
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2746/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2747/2800
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2748/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2749/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2750/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2751/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2752/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2753/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2754/2800
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2755/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2756/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2757/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2758/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2759/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2760/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 2761/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2762/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2763/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2764/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2765/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2766/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2767/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2768/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2769/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2770/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2771/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2772/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2773/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2774/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2775/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2776/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2777/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2778/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2779/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2780/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2781/2800
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2782/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 2783/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2784/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2785/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2786/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2787/2800
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2788/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2789/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2790/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2791/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2792/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2793/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2794/2800
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2795/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 2796/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 2797/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 2798/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 2799/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.0000e+00 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2800/2800
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0218 - val_accuracy: 0.0000e+00

# %% [markdown]
# # Q2.B. RBF

# %%
#write your code here
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def compute_distance(X, centroids, k):
    new_X = X.reshape((X.shape[0],1))
    centroids = centroids.reshape((k, 1))
    distances = np.zeros((X.shape[0],k))
    for i in range(centroids.shape[0]):
        diff = np.linalg.norm(new_X - centroids[i, :], ord=None, axis=1)
        distances[:, i] = np.square(diff)
    return distances

def update_centroids(label, X, k):
    new_X = X.reshape((X.shape[0],1))
    new_centroids = np.zeros((k, new_X.shape[1]))
    for i in range(k):
        new_centroids[i, :] = np.mean(new_X[label == i, :], axis=0)
    return new_centroids.reshape(k)

## compute centeroid of k clusters
def compute_clusters(X, k):
    max_itration = 100000
    clusters = np.random.choice(np.squeeze(X), size=k)
    prevClusters = clusters.copy()
    converged = False
    itr = 0
    while (not converged) and (itr < max_itration):
        distances = compute_distance(X,clusters, k)
        closest_cluster_to_data = np.argmin(distances, axis=1)
        clusters = update_centroids(closest_cluster_to_data,X,k)
        converged = np.linalg.norm(clusters - prevClusters) < 1e-6
        prevClusters = clusters.copy()
    return clusters


## computes phis or radius of each cluster
def compute_phis(X, centroids):
    center = centroids.reshape((centroids.shape[0], 1))
    new_x = X.reshape(X.shape[0], 1)
    distances = np.zeros((new_x.shape[0], center.shape[0]))
    for i in range(center.shape[0]):
        diff = np.linalg.norm(new_x - center[i, :], axis=1)
        distances[:, i] = np.sqrt(diff)

    min_dist = np.argmin(distances, axis=1)
    radius = np.zeros(center.shape)
    for i in range(center.shape[0]):
        close_to_i = new_x[min_dist == i, :]
        centroid_i = center[i, :]
        diff = close_to_i - centroid_i
        diff = diff**2
        su = np.sum(diff, axis=1)
        su = np.sqrt(su)
        su = su.reshape((su.shape[0], 1))
        radius[i, :] = np.mean(su, axis=0)
    return radius.reshape(center.shape[0])


class RBFNet(object):
    def __init__(self, k=2, lr=0.01, epochs=150):
        self.k = k
        self.lr = lr
        self.epochs = epochs
        self.w = np.random.randn(k)
        self.b = np.random.randn(1)

    def forward_pass(self, x):
        c = self.centers.reshape((self.k, 1))
        ph = self.stds.reshape(c.shape)
        diff = c - x
        diff = diff**2
        s = np.sum(diff, axis=1)
        s = s.reshape((self.k, 1))
        s = np.sqrt(s)
        s = s / ph
        s = s**2
        rbff = np.exp((-1 / 2) * s)
        predict = rbff.T.dot(self.w) + self.b
        return rbff.reshape(self.k), predict

    def train(self, X, y):
        self.centers = compute_clusters(X, self.k)

        self.stds = compute_phis(X, self.centers)

        # training ( SGD )
        for epoch in range(self.epochs):
            loss = []
            for i in range(X.shape[0]):
                # forward pass
                a, predict = self.forward_pass(X[i])

                loss.append((y[i] - predict)**2)

                # backpropagation
                error = -(y[i] - predict)

                # online update
                self.w = self.w - self.lr * a * error
                self.b = self.b - self.lr * error

            avg_loss = np.mean(loss)
            # if epoch % 10 == 0 or epoch == 0:
            #     print(f'epoch ====> {epoch} , loss : {avg_loss}')

    def test(self, X):
        y_pred = []
        for i in range(X.shape[0]):
            bases, out = self.forward_pass(X[i])
            y_pred.append(out)
        return np.array(y_pred)


def main():
    x =  np.arange(-3.14, 3.14, 0.01)
    y = np.sin(x)

    rbfnet = RBFNet(lr=0.01, k=2)
    rbfnet.train(x, y)

    # x_new = np.arange(-4.0, 4.0, 0.01)
    y_new = np.sin(x)
    
    y_predict = rbfnet.test(x)

    red_patch = mpatches.Patch(color='red', label='RBfN')
    blue_patch = mpatches.Patch(color='blue', label='expected')

    plt.plot(x, y_new, 'b--', x, y_predict, 'r--')
    plt.ylabel('Y / Predicted Value')
    plt.xlabel('X Value')
    plt.legend(handles = [red_patch,blue_patch])

    plt.tight_layout()
    plt.show()
    return rbfnet

rbf = None

if __name__ == '__main__':
    rbf = main()

# %% [markdown]
# # Q2.C. Compare

# %%
#write your code here
x_new = np.arange(-4.0, 4.0, 0.01)
y_new = np.sin(x_new)
    
y_predict_rbfn = rbf.test(x_new)

y_predict_mlp = model.predict(x_new)

red_patch = mpatches.Patch(color='red', label='RBfN')
blue_patch = mpatches.Patch(color='blue', label='expected')
green_path = mpatches.Patch(color='green', label='MLP')

plt.plot(x_new, y_new, 'b--', x_new, y_predict_rbfn, 'r--', x_new, 2* y_predict_mlp -1 ,'g--' )
plt.ylabel('Y / Predicted Value')
plt.xlabel('X Value')
plt.legend(handles = [red_patch,blue_patch, green_path])

plt.tight_layout()
plt.show()

# %% [markdown]
# # <font color='red'>Submission</font>
#
# 1. Sign up in [Gradescope](https://www.gradescope.com) with proper name and student ID and use the following code to join the class: <font color='red'>**D5372R**</font>
# 2. Fill in your full name (seperated by single spaces) and student ID in the beginning of this notebook.
# 3. After you're done with this notebook, you should do the following:
#   - Clear all outputs of the notebook.
#   ![clear all outputs](https://i.ibb.co/y6FrttB/Screen-Shot-2021-03-21-at-01-51-42.png)
#   - Run all of the cells (if you skipped a question just leave the cell unchanged), and make sure all of your outputs are correct.
#   ![run all](https://i.ibb.co/cgRcBZ0/Screen-Shot-2021-03-21-at-01-54-58.png)
#   - Save your notebook.
#
#   - If you're using Colab, download your notebook.
#   ![download ipynb](https://i.ibb.co/2KxYM6K/Screen-Shot-2021-03-21-at-02-03-50.png)
#
#   - Put the notebook file you just downloaded and `convert.py` in the same folder run the following command:
#   ```bash
#   python convert.py
#   ```
#   This will export your code for each question into a `.py` file.
#
#
#   according to the question number.
#   - There are 2 assignments in Gradescope:
#
#     You should upload your **codes** and your **notebook** in `HW2` section and your final report for all of the questions as a **single pdf** file in `HW2 - Report`. Autograder will automatically check for:
#     - `CI992_HW2.ipynb`
#     - `Q1.A. Kohonen.py`
#     - `Q1.B. Koohonen.py`
#     - `Q2.A. MLP.py`
#     - `Q2.B. RBF.py`
#     - `Q2.C. Compare.py`
#     - Your name and ID in the beginning of `.ipynb` file.
#
#     It is important that you <font color='red'>**don't**</font> change the names of these files before submission.
#
# 4. If you pass the autograder, you're good to go.
